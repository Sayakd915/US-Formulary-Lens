# %%
## Changing January text data to csv format
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Dataset-CodeFest '25/Jan_formulary_data.txt", sep="|")
df.to_csv("/content/drive/MyDrive/Dataset-CodeFest '25/Jan_formulary_data.csv", index = False)
df.head(20)
# Out:
#     FORMULARY_ID  FORMULARY_VERSION  CONTRACT_YEAR    RXCUI      NDC  \
# 0          25000                 13           2025  1551300  2143380
# 1          25000                 13           2025  1551306  2143480
# 2          25000                 13           2025  2058877  2143611
# 3          25000                 13           2025  2601758  2145780
# 4          25000                 13           2025  2601776  2146080
# 5          25000                 13           2025  2601770  2147180
# 6          25000                 13           2025  2601785  2148480
# 7          25000                 13           2025  2601746  2149580
# 8          25000                 13           2025  2601764  2150680
# 9          25000                 13           2025  2395779  2223680
# 10         25000                 13           2025  2058887  2237711
# 11         25000                 13           2025  2370174  2298026
# 12         25000                 13           2025  2170613  2311509
# 13         25000                 13           2025  2395785  2318280
# 14         25000                 13           2025  2370170  2397760
# 15         25000                 13           2025  1946836  2448354
# 16         25000                 13           2025  1946840  2481554
# 17         25000                 13           2025  1946844  2533754
# 18         25000                 13           2025  2679814  2534060
# 19         25000                 13           2025  2679812  2556260
#
#     TIER_LEVEL_VALUE QUANTITY_LIMIT_YN QUANTITY_LIMIT_AMOUNT  \
# 0                  3                 Y                     2
# 1                  3                 Y                     2
# 2                  3                 Y                     2
# 3                  3                 Y                     2
# 4                  3                 Y                     2
# 5                  3                 Y                     2
# 6                  3                 Y                     2
# 7                  3                 Y                     2
# 8                  3                 Y                     2
# 9                  3                 Y                     2
# 10                 3                 Y                     2
# 11                 5                 Y                   120
# 12                 4                 Y                     3
# 13                 3                 Y                     2
# 14                 5                 Y                   180
# 15                 5                 Y                    56
# 16                 5                 Y                    56
# 17                 5                 Y                    56
# 18                 5                 Y                    90
# 19                 5                 Y                    60
#
#    QUANTITY_LIMIT_DAYS PRIOR_AUTHORIZATION_YN STEP_THERAPY_YN
# 0                   28                      Y               N
# 1                   28                      Y               N
# 2                   28                      Y               N
# 3                   28                      Y               N
# 4                   28                      Y               N
# 5                   28                      Y               N
# 6                   28                      Y               N
# 7                   28                      Y               N
# 8                   28                      Y               N
# 9                   28                      Y               N
# 10                  28                      Y               N
# 11                  30                      Y               N
# 12                  28                      Y               N
# 13                  28                      Y               N
# 14                  30                      Y               N
# 15                  28                      Y               N
# 16                  28                      Y               N
# 17                  28                      Y               N
# 18                  30                      Y               N
# 19                  30                      Y               N

# %%
print(df_jan.isnull)
# Out:
# <bound method DataFrame.isnull of          FORMULARY_ID  FORMULARY_VERSION  CONTRACT_YEAR    RXCUI          NDC  \
# 0               25000                 13           2025  1551300      2143380
# 1               25000                 13           2025  1551306      2143480
# 2               25000                 13           2025  2058877      2143611
# 3               25000                 13           2025  2601758      2145780
# 4               25000                 13           2025  2601776      2146080
# ...               ...                ...            ...      ...          ...
# 1299068         25521                  8           2025  2690862  82950000124
# 1299069         25521                  8           2025  2682445  82950001201
# 1299070         25521                  8           2025  2048025  83257000541
# 1299071         25521                  8           2025  2684032  83296010012
# 1299072         25521                  8           2025  1248442  99207027675
#
#          TIER_LEVEL_VALUE QUANTITY_LIMIT_YN QUANTITY_LIMIT_AMOUNT  \
# 0                       3                 Y                     2
# 1                       3                 Y                     2
# 2                       3                 Y                     2
# 3                       3                 Y                     2
# 4                       3                 Y                     2
# ...                   ...               ...                   ...
# 1299068                 5                 Y                    24
# 1299069                 5                 Y                    96
# 1299070                 5                 N
# 1299071                 5                 Y                   120
# 1299072                 4                 N
#
#         QUANTITY_LIMIT_DAYS PRIOR_AUTHORIZATION_YN STEP_THERAPY_YN
# 0                        28                      Y               N
# 1                        28                      Y               N
# 2                        28                      Y               N
# 3                        28                      Y               N
# 4                        28                      Y               N
# ...                     ...                    ...             ...
# 1299068                  28                      Y               N
# 1299069                  28                      Y               N
# 1299070                                          N               N
# 1299071                  30                      Y               N
# 1299072                                          N               N
#
# [1299073 rows x 11 columns]>

# %%
df["TIER_LEVEL_VALUE"] = df["TIER_LEVEL_VALUE"].astype(int)
df["QUANTITY_LIMIT_AMOUNT"] = df["QUANTITY_LIMIT_AMOUNT"]
df["QUANTITY_LIMIT_DAYS"] = df["QUANTITY_LIMIT_DAYS"]

# %%
df_cleaned = df.dropna(subset=["TIER_LEVEL_VALUE", "QUANTITY_LIMIT_AMOUNT", "QUANTITY_LIMIT_DAYS"])
df_sampled = df_cleaned.sample(n=5000, random_state=42)
df_sampled.head(20)
# Out:
#          FORMULARY_ID  FORMULARY_VERSION  CONTRACT_YEAR    RXCUI          NDC  \
# 1299070         25521                  8           2025  2048025  83257000541
# 33994           25019                 13           2025   314088  76385010001
# 1231282         25494                  7           2025  1490026  70710138909
# 444879          25188                 10           2025   903703  42794002012
# 393262          25170                  8           2025   308493  24208078055
# 225983          25100                  9           2025  1049227  60951070070
# 401871          25174                  9           2025  2180671      2614511
# 429850          25184                  8           2025  1862701    597029074
# 352183          25155                  8           2025  1665444    143997722
# 776015          25316                  9           2025   863619  68382025601
# 484666          25202                  7           2025  1086784  62332023430
# 770052          25313                  9           2025  1362706     93873901
# 246224          25108                  9           2025   309329  42571025001
# 556556          25231                  8           2025   637551  63323068610
# 167577          25072                  8           2025   312075  24208043405
# 392721          25170                  8           2025   207391    338102541
# 693422          25278                  8           2025   848750  43068010802
# 1142482         25462                  7           2025   311027    169183411
# 1235818         25498                 11           2025  2200658    169430730
# 134246          25054                  9           2025  1000158      9470913
#
#          TIER_LEVEL_VALUE QUANTITY_LIMIT_YN QUANTITY_LIMIT_AMOUNT  \
# 1299070                 5                 N
# 33994                   2                 N
# 1231282                 5                 N
# 444879                  3                 N
# 393262                  3                 N
# 225983                  4                 Y                   180
# 401871                  3                 N
# 429850                  2                 Y                    60
# 352183                  4                 N
# 776015                  3                 Y                    60
# 484666                  2                 Y                    30
# 770052                  4                 N
# 246224                  2                 N
# 556556                  2                 N
# 167577                  2                 N
# 392721                  4                 N
# 693422                  5                 Y                    60
# 1142482                 2                 N
# 1235818                 3                 Y                    30
# 134246                  2                 N
#
#         QUANTITY_LIMIT_DAYS PRIOR_AUTHORIZATION_YN STEP_THERAPY_YN
# 1299070                                          N               N
# 33994                                            N               N
# 1231282                                          Y               N
# 444879                                           N               N
# 393262                                           N               N
# 225983                   30                      N               N
# 401871                                           N               N
# 429850                   30                      N               N
# 352183                                           N               N
# 776015                   30                      N               N
# 484666                   30                      N               N
# 770052                                           N               N
# 246224                                           N               N
# 556556                                           N               N
# 167577                                           N               N
# 392721                                           N               N
# 693422                   30                      Y               N
# 1142482                                          N               N
# 1235818                  30                      Y               N
# 134246                                           N               N

# %%
##Distribution along Tier Levels

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

plt.figure(figsize=(8, 5))
sns.countplot(x="TIER_LEVEL_VALUE", data=df_sampled, palette="viridis")
plt.title("Distribution of Drugs by Tier Level")
plt.xlabel("Tier Level")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-33-45a38a0bd704>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="TIER_LEVEL_VALUE", data=df_sampled, palette="viridis")

# %%
##Quantity Limit Amounts vs Days
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df_sampled["QUANTITY_LIMIT_AMOUNT"], y=df_sampled["QUANTITY_LIMIT_DAYS"], alpha=0.5)
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=10))
plt.xticks(rotation=45)
plt.xlabel("Quantity Limit Amount")
plt.ylabel("Quantity Limit Days")
plt.title("Quantity Limit Days vs. Amount")

plt.show()

# %%
df_sampled.to_csv("/content/drive/MyDrive/Dataset-CodeFest '25/sampled_jan_data.csv", index=False) #Sampled data saved into CSV
